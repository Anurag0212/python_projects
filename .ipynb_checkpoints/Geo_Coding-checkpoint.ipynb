# %% [markdown]
# # Geo Coding using Python

# %%
import pandas
from geopy.geocoders import Nominatim

# %% [markdown]
# # Cordinates Using for loop

# %%
#Importing files with address
df = pandas.read_csv("supermarkets.csv")
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
#Addin latitude and longitude using for loop
for x in range(len(df.index)):
    addr = list(df.iloc[x,1:4])
    code = nom.geocode(str(addr))
    if code != None:
        df.ix[x,"latitude"] = code.latitude
        df.ix[x,"longitude"] = code.longitude
    else:
        df.ix[x,"latitude"] = "N/A"
        df.ix[x,"longitude"] = "N/A"
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees latitude longitude
# 0          8  37.7565  -122.429
# 1         15      N/A       N/A
# 2         25  37.7557  -122.429
# 3         10   37.753  -122.432
# 4         12  37.7521   -122.43
# 5         20  37.7537  -122.433

# %% [markdown]
# # Cordinates Using apply and Lambda function

# %%
new_df = pandas.read_csv("supermarkets.csv")
new_df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
#Concatinating full address in one column
new_df["Full Address"] = new_df["Address"]+", "+new_df["City"]+", "+new_df["State"]

#Adding a new columns which will store the coordinates of the location
new_df["coordinates"] = new_df["Full Address"].apply(nom.geocode)

#Adding latitude and longitude columns to the existing dataframe
new_df["latitude"]=new_df["coordinates"].apply(lambda x: x.latitude if x!= None else None)
new_df["longitude"]=new_df["coordinates"].apply(lambda x: x.longitude if x!= None else None)

#Printing the result
new_df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees                                  Full Address  \
# 0          8         3666 21st St, San Francisco, CA 94114
# 1         15       735 Dolores St, San Francisco, CA 94119
# 2         25  332 Hill St, San Francisco, California 94114
# 3         10         3995 23rd St, San Francisco, CA 94114
# 4         12    1056 Sanchez St, San Francisco, California
# 5         20      551 Alvarado St, San Francisco, CA 94114
#
# ...
